# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('inu_neko_orderline_clean.csv')
df
# Out:
#        trans_id      prod_upc  cust_id             trans_timestamp  \
# 0      10300097  719638485153  1001019  2021-01-01 07:35:21.439873
# 1      10300093   73201504044  1001015  2021-01-01 09:33:37.499660
# 2      10300093  719638485153  1001015  2021-01-01 09:33:37.499660
# 3      10300093  441530839394  1001015  2021-01-01 09:33:37.499660
# 4      10300093  733426809698  1001015  2021-01-01 09:33:37.499660
# ...         ...           ...      ...                         ...
# 38218  10327860  287663658863  1022098  2021-06-30 15:37:12.821020
# 38219  10327960  140160459467  1022157  2021-06-30 15:45:09.872732
# 38220  10328009  425361189561  1022189  2021-06-30 15:57:44.295104
# 38221  10328089  733426809698  1022236  2021-06-30 15:59:29.801593
# 38222  10328109  717036112695  1011924  2021-06-30 17:30:52.205912
#
#        trans_year  trans_month  trans_day  trans_hour  trans_quantity  \
# 0            2021            1          1           1               1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38223 entries, 0 to 38222
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   trans_id          38223 non-null  int64
#  1   prod_upc          38223 non-null  int64
#  2   cust_id           38223 non-null  int64
#  3   trans_timestamp   38223 non-null  object
#  4   trans_year        38223 non-null  int64
#  5   trans_month       38223 non-null  int64
#  6   trans_day         38223 non-null  int64
#  7   trans_hour        38223 non-null  int64
#  8   trans_quantity    38223 non-null  int64
#  9   cust_age          38223 non-null  int64
#  10  cust_state        38223 non-null  object
#  11  prod_price        38223 non-null  float64
#  12  prod_title        38223 non-null  object
#  13  prod_category     38223 non-null  object
#  14  prod_animal_type  38223 non-null  object
#  15  total_sales       38223 non-null  float64
# ...

# %% [markdown]
# Question 1: Duplicate Records
# How many duplicate transaction records are there? Do not count the first occurence as a duplicate. Assign your answer to the variable dup_rows

# %%
dup_rows = df.duplicated().sum()
#print(dup_rows)

# %% [markdown]
# Question 2: Drop Duplicate Records
# Drop the duplicated records and assign the output DataFrame to a new variable called df_cleaned. Use this from now on.

# %%
df_cleaned = df.drop_duplicates(subset=None,keep='last', ignore_index=False)

# %% [markdown]
# Question 3: Consistent Formatting
# Fix the inconsistencies in the column cust_state.

# %%
# your code here
df_cleaned["cust_state"].unique()
df_cleaned["cust_state"].replace(["NY","PA","NJ","CT"],["New York","Pennsylvania","New Jersey","Connecticut"], inplace= True)

# %% [markdown]
# Question 4: Fistful of Dollars I
# Validate the prices in prod_price. Remove any rows that are obviously wrong

# %%
lower_bound = 1
upper_bound = 300
df_cleaned = df_cleaned[(df_cleaned['prod_price'] >= lower_bound) & (df['prod_price'] <= upper_bound)]
df_cleaned.head(50)
# Out:
#     trans_id      prod_upc  cust_id             trans_timestamp  trans_year  \
# 0   10300097  719638485153  1001019  2021-01-01 07:35:21.439873        2021
# 1   10300093   73201504044  1001015  2021-01-01 09:33:37.499660        2021
# 2   10300093  719638485153  1001015  2021-01-01 09:33:37.499660        2021
# 3   10300093  441530839394  1001015  2021-01-01 09:33:37.499660        2021
# 4   10300093  733426809698  1001015  2021-01-01 09:33:37.499660        2021
# 5   10300091  344934101144  1001012  2021-01-01 10:08:32.241027        2021
# 6   10300096  717036112695  1001018  2021-01-01 10:43:40.372766        2021
# 7   10300103  242313721729  1001025  2021-01-01 11:05:32.193258        2021
# 8   10300100  100469015054  1001022  2021-01-01 11:39:46.749952        2021
# 9   10300102  287663658863  1001024  2021-01-01 11:44:27.467186        2021
# 10  10300101  441530839394  1001023  2021-01-01 12:14:47.132247        2021
# ...

# %% [markdown]
# Question 5: Fistful of Dollars II
# Correct the values in the total_sales column. Use prod_price and trans_quantity.

# %%
df_cleaned['total_sales'] = df_cleaned.prod_price * df_cleaned.trans_quantity
df_cleaned['total_sales'] = df_cleaned['total_sales'].astype('float')

# %% [markdown]
# Question 6: Missing Values I
# How many missing values are there?

# %%
num_nans = df_cleaned.isnull().sum().sum()
df_cleaned = num_nans

# %% [markdown]
# Question 7: Missing Values II
# Drop any columns with missing values.

# %%
drop_any = df_cleaned.dropna(axis='column', how='any')
df_cleaned = df_cleaned[drop_any]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 drop_any = df_cleaned.dropna(axis='column', how='any')
#       2 df_cleaned = df_cleaned[drop_any]
#
# AttributeError: 'numpy.int64' object has no attribute 'dropna'
